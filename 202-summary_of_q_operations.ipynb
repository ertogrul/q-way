# %%
from qiskit import *
qiskit.__version__
# Out:
# '0.14.1'

# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# %qiskit_copyright
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td>Qiskit</td><td>0.19.2</td></tr><tr><td>Terra</td><td>0.14.1</td></tr><tr><td>Aer</td><td>0.5.1</td></tr><tr><td>Ignis</td><td>0.3.0</td></tr><tr><td>Aqua</td><td>0.7.1</td></tr><tr><td>IBM Q Provider</td><td>0.7.1</td></tr><tr><th>System information</th></tr><tr><td>Python</td><td>3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)]</td></tr><tr><td>OS</td><td>Darwin</td></tr><tr><td>CPUs</td><td>6</td></tr><tr><td>Memory (Gb)</td><td>16.0</td></tr><tr><td colspan='2'>Fri Oct 02 18:56:22 2020 CEST</td></tr></table>
# ...

# %%
#

# %%
#

# %%
#

# %%
# testing if values of less than pi and more than pi/2 are producing bias toward

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.quantum_info import state_fidelity
from qiskit import BasicAer
backend = BasicAer.get_backend('unitary_simulator')

# %%
q = QuantumRegister(2)

# %%
qc = QuantumCircuit(q)
#qc.rx(q[0])
qc.cx(q[0],q[1])
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#        [0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j],
#        [0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j]])

# %%
#

# %%
#

# %%
#

# %%
# SUMMARY OF OPERATIONS
#
# Useful additional packages
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import pi

# %%
from qiskit import QuantumCircuit, ClassicalRegister, QuantumRegister, execute
from qiskit.tools.visualization import circuit_drawer
from qiskit.quantum_info import state_fidelity
from qiskit import BasicAer

backend = BasicAer.get_backend('unitary_simulator')

# %%
q = QuantumRegister(1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.u3(pi/2,pi/2,pi/2,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.707+0.j   , -0.   -0.707j],
#        [ 0.   +0.707j, -0.707+0.j   ]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.u2(pi/2,pi/2,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.707+0.j   , -0.   -0.707j],
#        [ 0.   +0.707j, -0.707+0.j   ]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.u1(pi/2,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.+0.j, 0.+0.j],
#        [0.+0.j, 0.+1.j]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.id(q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.+0.j, 0.+0.j],
#        [0.+0.j, 1.+0.j]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.x(q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[0.+0.j, 1.-0.j],
#        [1.+0.j, 0.+0.j]])

# %%
######################

# %%
# ok, checking if x gate is equal to u3(pi, 0, pi)
qc = QuantumCircuit(q)
qc.u3(pi,0,pi,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[0.+0.j, 1.-0.j],
#        [1.+0.j, 0.+0.j]])

# %%
# correct :)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.y(q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.+0.j, -0.-1.j],
#        [ 0.+1.j,  0.+0.j]])

# %%
# checking if  Y gate is equal to u3(pi,pi/2,pi/2)
qc = QuantumCircuit(q)
qc.u3(pi,pi/2,pi/2,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.+0.j, -0.-1.j],
#        [ 0.+1.j,  0.+0.j]])

# %%
# correct :)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.z(q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 1.+0.j,  0.+0.j],
#        [ 0.+0.j, -1.+0.j]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.h(q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.707+0.j,  0.707-0.j],
#        [ 0.707+0.j, -0.707+0.j]])

# %%
#checking if u2(0,pi) also works
qc = QuantumCircuit(q)
qc.u2(0,pi,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.707+0.j,  0.707-0.j],
#        [ 0.707+0.j, -0.707+0.j]])

# %%
# it works

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.s(q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.+0.j, 0.+0.j],
#        [0.+0.j, 0.+1.j]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.sdg(q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.+0.j, 0.+0.j],
#        [0.+0.j, 0.-1.j]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.tdg(q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.   +0.j   , 0.   +0.j   ],
#        [0.   +0.j   , 0.707-0.707j]])

# %%
#check
qc = QuantumCircuit(q)
qc.u1(pi/4,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.   +0.j   , 0.   +0.j   ],
#        [0.   +0.j   , 0.707+0.707j]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.rx(pi/2,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.707+0.j   , -0.   -0.707j],
#        [ 0.   -0.707j,  0.707+0.j   ]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc.ry(pi/2,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 0.707+0.j   , -0.707-0.j   ],
#        [ 0.   -0.707j,  0.   -0.707j]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.rz(pi/2,q)
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.+0.j, 0.+0.j],
#        [0.+0.j, 0.+1.j]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# To describe states of a multi-qubit system, the tensor product is used 
# to “glue together” operators and basis vectors
# TENSOR PRODUCT: 
# tensor product V ⊗ W of two vector spaces V and W (over the same field) is itself a vector space,
# endowed with the operation of bilinear composition, denoted by ⊗, from ordered pairs 
# in the Cartesian product V × W to V ⊗ W in a way that generalizes the outer product.

# %%
q = QuantumRegister(2)

# %%
qc = QuantumCircuit(q)
qc.cx(q[0],q[1])
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#        [0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j],
#        [0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j]])

# %% [markdown]
# ![image.png](attachment:image.png)
# #
# # MSB - most significant bit
# # LSB - least significant bit

# %%
qc = QuantumCircuit(q)
qc.cy(q[0],q[1])
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#        [0.+0.j, 0.+0.j, 0.+0.j, 0.-1.j],
#        [0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j],
#        [0.+0.j, 0.+1.j, 0.+0.j, 0.+0.j]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
qc = QuantumCircuit(q)
qc.cz(q[0],q[1])
qc.draw()

# %%
job = execute(qc, backend)
job.result().get_unitary(qc, decimals=3)
# Out:
# array([[ 1.-0.j,  0.+0.j,  0.+0.j,  0.+0.j],
#        [ 0.+0.j,  1.-0.j,  0.+0.j,  0.+0.j],
#        [ 0.+0.j,  0.+0.j,  1.-0.j,  0.+0.j],
#        [ 0.+0.j,  0.+0.j,  0.+0.j, -1.+0.j]])
